# %%
print('Hello world!')
# Out:
# Hello world!

# %%
type('Hello world!')
# Out:
# str

# %%
#2. Set a loop for x from 0 to 9, and print x if x<5.
for x in range(10):
    if x<5:
        print(x)
    else:
        pass
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#3. What is the data type of ‘100’? How to change it to the float type? Print the right data with its type.
type('100')
changed_val = float('100')
type(changed_val)
# Out:
# float

# %%
#4. Set a value equals to None, what is its type?
val = None 
print(val,type(val))
# Out:
# None <class 'NoneType'>

# %%
#5. What is round(x) in Python? Find the value when x=-0.05 y=0,1,2.
x = -0.05 
y = 0,1,2
print(round(x),round(x,1),round(x,2)) #1,2 is the numbers after decimal
# Out:
# 0 -0.1 -0.05

# %%
#6. Set a Python program to ask you your name and age. And then print the answer.
name = input('Enter name:')
age = input('Enter age: ')
print(name,age)
print('%d square is %d' % (10,11)) #for numbers
print("Hi! I'm {} and I am {} years old.".format(name,age))
#%d for numbers in string format
# Out:
# Enter name:s
# Enter age: 24
# s 24
# 10 square is 11
# Hi! I'm s and I am 24 years old.
